# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

# Essas configurações definem o número máximo de linhas e colunas a serem exibidas como None, o que significa que não há limite.
pd.set_option('display.max_rows', 6)  # Mostrar 5 linhas
pd.set_option('display.max_columns', None)  # Mostrar todas as colunas

# URL da API externa
API_URL = 'https://microworkcloud.com.br/api/integracao/terceiro'
API_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJqdGkiOiJjYjA5YjI5ZC0xMWI0LTRhZjgtYjQwOC03OWVmZjVhNWI3MzAiLCJvcmciOiJvcmcwMDA0NDQifQ.izk8b4ni8eyP3r2y_tpDu10iRiWohbTpsiQgk4YVV-s"
# Cabeçalhos (headers) que você deseja enviar na requisição
headers = {
    'Content-Type': 'application/json',
    'Authorization': f'Bearer { API_KEY }',
}

df_result = []
dtInicial = "2022-01-16"
dtFinal = "2024-02-16"

body = {
            "idrelatorioconfiguracao": 360,
            "idrelatorioconsulta": 178,
            "idrelatorioconfiguracaoleiaute": 845,
            "idrelatoriousuarioleiaute": None,
            "ididioma": 1,
            "listaempresas": [3],
            "filtros": f"Ano=2024; \
                Departamento=16; \
                Estrutura=4; \
                MesAcumulado=0; \
                NaoExibirLinhaZerada=True; \
                PeriodoInicial=2024-01-16; \
                PeriodoFinal=2024-08-16; \
                Producao=True"
        }

try:
    response = requests.post(API_URL, headers=headers, json=body)
    
    if response.status_code == 200:
        # Converte a resposta JSON em um DataFrame do Pandas
        data_json = response.json()
        df_result = pd.DataFrame(data_json)
    
        if df_result.empty:
            df_result = []
            
        # df_result["descricao"] = df_result["descricao"].replace({
        #     "1 - RECEITAS": "RECEITAS",
        #     "1 - CUSTOS": "CUSTOS",
        #     "1 - RESULTADO": "RESULTADO"
        # })
        
        # df_selecionados = df_result[df_result["descricao"].isin(["RECEITAS", "CUSTOS", "RESULTADO"])]
        # df_selecionados = df_selecionados[["descricao", "valororcadojaneiro", "valorrealizadojaneiro", "valororcadofevereiro", "valorrealizadofevereiro", "valororcadomarco", "valorrealizadomarco"]]
        # df_selecionados = df_selecionados.set_index("descricao")
        
        # # Gerar o gráfico de barras
        # ax = df_selecionados[['valororcadojaneiro', 'valororcadofevereiro', 'valororcadomarco']].plot(
        #     kind='bar',
        #     figsize=(10, 6),
        #     color=['#1f77b4', '#ff7f0e', '#2ca02c']  # Cores diferentes para cada mês
        # )

        # # for p in ax.patches:
        # #     ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
        # #                 ha='center', va='center', xytext=(0, 10), textcoords='offset points')
            
        # # Adicionar título e rótulos
        # plt.title('Comparação Orçado vs Realizado')
        # plt.xlabel('Descrição')
        # plt.ylabel('Valores (R$)')
        # plt.xticks(rotation=0)  # Rota os rótulos do eixo x
        # plt.legend(title='Período')
        # plt.tight_layout()

        # # Mostrar o gráfico
        # plt.show()
        
        display(df_result)
    else:
        print("Ooops! algo deu errado.\nresponse.status_code: ",response.status_code)
    
except requests.exceptions.RequestException as e:
    print("Erro ao fazer a solicitação:", e)
# Out:
# []
