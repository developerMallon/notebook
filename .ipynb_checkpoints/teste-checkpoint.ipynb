# %%
pip install pandas

# %%
import requests
import pandas as pd

# URL da API externa
url = 'https://microworkcloud.com.br/api/integracao/terceiro'
API_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJqdGkiOiJjYjA5YjI5ZC0xMWI0LTRhZjgtYjQwOC03OWVmZjVhNWI3MzAiLCJvcmciOiJvcmcwMDA0NDQifQ.izk8b4ni8eyP3r2y_tpDu10iRiWohbTpsiQgk4YVV-s"
# Cabeçalhos (headers) que você deseja enviar na requisição
headers = {
    'Content-Type': 'application/json',
    'Authorization': f'Bearer { API_KEY }',
}

# Corpo para consulta das VENDAS
dataVendas = {
    "idrelatorioconfiguracao": 138,
    "idrelatorioconsulta": 55,
    "idrelatorioconfiguracaoleiaute": 138,
    "idrelatoriousuarioleiaute": 216,
    "ididioma": 1,
    "listaempresas": [3, 4, 5, 6],
    "filtros": "IntermediacaoMarketplace=null; TipoMovimentoInterno=1,3,4,5,6,8,9,11,14,15,16,17,28,29,30,31,32,33,34,33,34,35,36,18,21,22,23,24,25,26,27,44; Consultor=null; MarcaMercadoria=null; TipoOperacao=null; CodigoMercadoria=null; Estoquista=null; MarcaVeiculo=null; TipoVeiculo=null; ModeloVeiculo=null; DataMovimentacaoInicial=2023-09-01; Pessoa=null; Vendedor=null; TributacaoEstadual=null; TipoMovimentoUsuario=16,418,17,257,228,286,18,504,461,67,407,68,275,246,304,69,493,450,25,406,26,276,247,305,27,492,449,37,391,38,264,235,293,39,477,434,40,402,41,249,220,278,42,488,445,385,387,388,386,389,393,390,479,436,55,425,56,265,236,294,57,511,468,31,426,32,266,237,295,33,512,469,646,647,648,649,650,651,652,653,654,637,638,639,640,641,642,643,644,645,565,566,567,568,569,570,571,572,573,574,575,576,577,578,579,580,581,582,583,584,585,586,587,588,589,590,591,592,593,594,595,596,597,598,599,600,547,548,549,550,551,552,553,554,555,556,557,558,559,560,561,562,563,564,28,397,29,251,222,280,30,483,440,538,543,545,546,541,540,544,542,539,58,392,59,252,223,281,60,478,435,34,428,35,268,239,297,36,514,471,361,366,399,365,364,362,363,485,442,217,401,219,277,248,306,218,487,444; Gerarsaldos=False;  DataMovimentacaoFinal=2023-09-23; RegimeMonofasico=null; TipoMercadoria=null; TipoLocalizacao=null"
}

# Corpo para consulta das METAS
dataMetas = {
    "idrelatorioconfiguracao": 320,
    "idrelatorioconsulta": 154,
    "idrelatorioconfiguracaoleiaute": 320,
    "idrelatoriousuarioleiaute": 175,
    "ididioma": 1,
    "listaempresas": [1, 2, 3, 4, 5, 6, 7, 8, 9],
    "filtros": "DataMovimentoInicial=2023-09-01;  DataMovimentoFinal=2023-09-30; TipoMovimentoUsuario=null; TipoMercadoria=null; ModeloVeiculo=null; TipoVendaVeiculo=null; TipoOS=null; TipoServico=null; CodigoPessoa=null; GrupoPessoa=null; TipoMeta=4,5; TipoAtividade=null"
}

# VENDAS - Faz a requisição POST com os cabeçalhos e dados especificados
response = requests.post(url, headers=headers, json=dataVendas)

# Verifica se a requisição foi bem-sucedida (código de status HTTP 200)
if response.status_code == 200:
    # Converte a resposta JSON em um DataFrame do Pandas
    data_json = response.json()
    dfVendas = pd.DataFrame(data_json)

    # Função personalizada para copiar "PessoaConsultor" para "PessoaVendedor" se não for nulo
    def copiar_pessoa_consultor(row):
        if pd.notna(row['pessoaconsultor']):
            return row['pessoaconsultor']
        else:
            return row['pessoavendedor']

    # Aplica a função personalizada à coluna "PessoaVendedor"
    dfVendas['pessoavendedor'] = dfVendas.apply(copiar_pessoa_consultor, axis=1)

    # Lista de "PessoaVendedor" que você deseja excluir
    vendedores_a_excluir = ["ADRIANO SCHELBAUER", "DANIELE CRISTINA BELENA", "RAFAEL DOS SANTOS CARDOSO"]

    # Cria um novo DataFrame excluindo as linhas com os "PessoaVendedor" especificados
    dfVendas = dfVendas.loc[~dfVendas['pessoavendedor'].isin(vendedores_a_excluir)]

    # Exibe o DataFrame como uma tabela
    display(dfVendas.head())
else:
    print('Erro na requisição. Código de status HTTP:', response.status_code)
    print('Resposta da API:', response.text)

# METAS - Faz a requisição POST com os cabeçalhos e dados especificados
response = requests.post(url, headers=headers, json=dataMetas)

# Verifica se a requisição foi bem-sucedida (código de status HTTP 200)
if response.status_code == 200:
    # Converte a resposta JSON em um DataFrame do Pandas
    data_json = response.json()
    dfMetas = pd.DataFrame(data_json)

    # Lista de "PessoaVendedor" que você deseja excluir
    pessoas_a_excluir = ["MALLON CONCESSIONARIA DE VEICULOS COMERCIAIS LTDA", "JOAO VITOR AMANCIO DE OLIVEIRA", "SAMUEL DVOJATZKI"]

    # Cria um novo DataFrame excluindo as linhas com os "PessoaVendedor" especificados
    dfMetas = dfMetas.loc[~dfMetas['nomepessoa'].isin(pessoas_a_excluir)]

    # # Exibe o DataFrame como uma tabela
    display(dfMetas.head())
else:
    print('Erro na requisição. Código de status HTTP:', response.status_code)
    print('Resposta da API:', response.text)
# Out:
#              datamovimentacao empresareduzida         pessoaconsultor  \
# 0  2023-09-01T08:16:50.876958             MMA                    None
# 1   2023-09-01T08:39:59.87546             MMA  DOUGLAS FELIPE SCHULTZ
# 2   2023-09-01T08:39:59.87546             MMA  DOUGLAS FELIPE SCHULTZ
# 3   2023-09-01T08:39:59.87546             MMA  DOUGLAS FELIPE SCHULTZ
# 4  2023-09-01T08:42:46.986705             MRS     GABRIEL FELIX LEITE
#
#                 pessoavendedor     tipomercadoria  \
# 0  EMERSON LUIZ DE SOUZA PINTO          1 - RENOV
# 1       DOUGLAS FELIPE SCHULTZ    1 - GENUINA C&O
# 2       DOUGLAS FELIPE SCHULTZ    1 - GENUINA C&O
# 3       DOUGLAS FELIPE SCHULTZ  4 - LUBRIFICANTES
# 4          GABRIEL FELIX LEITE    1 - GENUINA C&O
#
#                           tipomovimento     codigomercadoria  \
# 0                          VENDA BALCÃO      A02425098010080
# 1                    USO FIRMA POR O.S.          A0000160521
# ...
