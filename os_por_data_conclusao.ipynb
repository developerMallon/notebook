# %%
import requests
import pandas as pd

def formatar(x):
    value = x
    value = value.replace(".", "")
    value = value.replace(",", ".")
    return float(value)


# Essas configurações definem o número máximo de linhas e colunas a serem exibidas como None, o que significa que não há limite.
pd.set_option('display.max_rows', 6)  # Mostrar 5 linhas
pd.set_option('display.max_columns', None)  # Mostrar todas as colunas

# URL da API externa
API_URL = 'https://microworkcloud.com.br/api/integracao/terceiro'
API_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJqdGkiOiJjYjA5YjI5ZC0xMWI0LTRhZjgtYjQwOC03OWVmZjVhNWI3MzAiLCJvcmciOiJvcmcwMDA0NDQifQ.izk8b4ni8eyP3r2y_tpDu10iRiWohbTpsiQgk4YVV-s"
# Cabeçalhos (headers) que você deseja enviar na requisição
headers = {
    'Content-Type': 'application/json',
    'Authorization': f'Bearer { API_KEY }',
}

df_result = []

body = {
       "idrelatorioconfiguracao": 393,
                    "idrelatorioconsulta": 95,
                    "idrelatorioconfiguracaoleiaute": 393,
                    "idrelatoriousuarioleiaute": 292,
                    "ididioma": 1,
                    "listaempresas": [2,3,4,5,6],
                    "filtros": f"ConsultorFechamento=null;\
        VeiculoCliente=null;\
        AnoInicial=0;\
        AnoFinal=999999999;\
        IdsServicos=null;\
        OSSituacao=null;\
        Tiposervico=null;\
        Municipio=null;\
        Tecnico=null;\
        Periododeconclusaoinicial=2024-10-02;\
        Periododeconclusaofinal=2024-10-02;\
        Tipoitem=3,1,4,2;\
        TipoMovimentoMercadoria=null;\
        Modelo=null;\
        Pessoa=null;\
        Tipodeordemdeservico=null;\
        Consultor=null;\
        NumeroOS=null;\
        TipoDeVeiculoModelo=null;\
        TipoVeiculoOS=null;\
        NumeroContratoFrotista=;\
        EquipeAtendimentoFrotista=null;\
        ItensServicosCancelados=False;\
        TipoRecepcao=null;\
        EstadoVeiculo=null;\
        TipoOrdemServicoInterno=null;\
        TipoBaixaDocumento=null;\
        NomeEmissaoDocumento=null;\
        SituacaoConcluidaNF=null;\
        IdsMercadorias=null;\
        SomenteManutencaoFrotista=False;\
        Segmento=null;\
        FontePagadora=null;\
        ConsiderarTecnico=True"
     }

try:
    response = requests.post(API_URL, headers=headers, json=body)
    
    if response.status_code == 200:
        # Converte a resposta JSON em um DataFrame do Pandas
        data_json = response.json()
        df_result = pd.DataFrame(data_json)
    
        if df_result.empty:
            df_result = "Vazio"
        else:
            display(df_result)
            
    else:
        print("Ooops! algo deu errado.\nresponse.status_code: ",response.status_code)
    
except requests.exceptions.RequestException as e:
    print("Erro ao fazer a solicitação:", e)
# Out:
#                databaixa empresa  numero                        ostipo  \
# 0    2024-10-02T00:00:00     MRS   11751    C3 - CLIENTES MBB PROMOCAO
# 1    2024-10-02T00:00:00     MRS   11751    C3 - CLIENTES MBB PROMOCAO
# 2    2024-10-02T00:00:00     MRS   11751  SA - SERVIÇOS ADICIONAIS C&O
# ..                   ...     ...     ...                           ...
# 168  2024-10-02T00:00:00     MMA   85517       C1V - CLIENTES VANS MBB
# 169  2024-10-02T00:00:00     MMA   85518          C5MTS - CLIENTES MTS
# 170  2024-10-02T00:00:00     MMA   85518          C5MTS - CLIENTES MTS
#
#      idpessoaconsultorabertura          pessoaconsultor  \
# 0                           95      RAFAEL TEZZA GUEDES
# 1                           95      RAFAEL TEZZA GUEDES
# 2                           95      RAFAEL TEZZA GUEDES
# ..                         ...                      ...
# 168                         77   DOUGLAS FELIPE SCHULTZ
# 169                         45  DANIEL DEMBISKI DE LIMA
# 170                         45  DANIEL DEMBISKI DE LIMA
#
#                       vendedor                           pessoa  \
# 0    ROBSON ANTONIO BECKHEUSER       MUNICIPIO DE LEOBERTO LEAL
# 1                         None       MUNICIPIO DE LEOBERTO LEAL
# 2                         None       MUNICIPIO DE LEOBERTO LEAL
# ..                         ...                              ...
# 168                       None  MOBELLO COMERCIO DE MOVEIS LTDA
# 169    DANIEL DEMBISKI DE LIMA                  PAULO GROSSKOPF
# 170                       None                  PAULO GROSSKOPF
#
#                modelo     placa  totalmercadoria  totalservico  totalcortesia  \
# 0     ATEGO 2730 K/36  RLK-8F07         17086.99           0.0            0.0
# 1     ATEGO 2730 K/36  RLK-8F07             0.00        1749.0            0.0
# 2     ATEGO 2730 K/36  RLK-8F07             0.00         396.0            0.0
# ..                ...       ...              ...           ...            ...
# 168  416 CDI SPRINTER  SEM-7H59             0.00         608.0            0.0
# 169        ATEGO 2430  MML-9065            10.00           0.0            0.0
# 170        ATEGO 2430  MML-9065             0.00          80.0            0.0
#
#      valortotal  valortotalacrescimo  valortotaldesconto  \
# 0      17086.99                  0.0             6003.53
# 1       1749.00                  0.0                0.00
# 2        396.00                  0.0                0.00
# ..          ...                  ...                 ...
# 168      608.00                  0.0                0.00
# 169       10.00                  0.0                0.60
# 170       80.00                  0.0                0.00
#
#                   datahorabaixa  descricaonotafiscal   tipomercadoria  \
# 0    2024-10-02T13:33:12.294152         NF-E 25156/1  1 - GENUINA C&O
# 1    2024-10-02T13:35:13.424746         NFS-E 9683/1             None
# 2    2024-10-02T13:35:13.424746         NFS-E 9683/1             None
# ..                          ...                  ...              ...
# 168  2024-10-02T17:13:02.611249  NFS-E 202452496/RP1             None
# 169  2024-10-02T14:12:24.024877        NF-E 147007/1           8 - OM
# 170  2024-10-02T14:13:47.973431  NFS-E 202452495/RP1             None
#
#     mercadoriamovimentotipo
# 0            VENDA POR O.S.
# 1                      None
# 2                      None
# ..                      ...
# 168                    None
# 169    VENDA POR O.S. - MTS
# 170                    None
#
# [171 rows x 20 columns]
